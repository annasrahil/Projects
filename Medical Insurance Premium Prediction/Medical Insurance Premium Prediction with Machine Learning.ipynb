# %% [markdown]
# # IMPORT LIBRARIES AND DATASETS

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# read the csv file 
insurance_df = pd.read_csv('insurance.csv')

# %%
insurance_df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
insurance_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %% [markdown]
# # PERFORM EXPLORATORY DATA ANALYSIS - PART 1

# %%
insurance_df.isnull()
# Out:
#         age    sex    bmi  children  smoker  region  charges
# 0     False  False  False     False   False   False    False
# 1     False  False  False     False   False   False    False
# 2     False  False  False     False   False   False    False
# 3     False  False  False     False   False   False    False
# 4     False  False  False     False   False   False    False
# ...     ...    ...    ...       ...     ...     ...      ...
# 1333  False  False  False     False   False   False    False
# 1334  False  False  False     False   False   False    False
# 1335  False  False  False     False   False   False    False
# 1336  False  False  False     False   False   False    False
# 1337  False  False  False     False   False   False    False
#
# [1338 rows x 7 columns]

# %%
insurance_df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
# check if there are any Null values
sns.heatmap(insurance_df.isnull(), yticklabels = False, cbar = False, cmap="Blues")
# Out:
# <Axes: >

# %%
# check if there are any Null values
insurance_df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
# Check the dataframe info
insurance_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
insurance_df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
numeric_insurance_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 numeric_insurance_df
#
# NameError: name 'numeric_insurance_df' is not defined

# %%
# Grouping by region to see any relationship between region and charges
# Seems like south east region has the highest charges and body mass index
region_insurance_df = insurance_df.drop(['sex', 'smoker'], axis = 1)
df_region = region_insurance_df.groupby('region').mean()
df_region

# %% [markdown]
# # PERFORM FEATURE ENGINEERING

# %%
# Check unique values in the 'sex' column
insurance_df['sex'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
# convert categorical variable to numerical
insurance_df['sex'] = insurance_df['sex'].apply(lambda x : 0 if x == 'female' else 1)

# %%
insurance_df.head()
# Out:
#    age  sex     bmi  children smoker     region      charges
# 0   19    0  27.900         0    yes  southwest  16884.92400
# 1   18    1  33.770         1     no  southeast   1725.55230
# 2   28    1  33.000         3     no  southeast   4449.46200
# 3   33    1  22.705         0     no  northwest  21984.47061
# 4   32    1  28.880         0     no  northwest   3866.85520

# %%
# Check the unique values in the 'smoker' column
insurance_df['smoker'].unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
# Convert categorical variable to numerical 
insurance_df['smoker'] = insurance_df['smoker'].apply(lambda x: 0 if x == 'no' else 1)

# %%
insurance_df.head()
# Out:
#    age  sex     bmi  children  smoker     region      charges
# 0   19    0  27.900         0       1  southwest  16884.92400
# 1   18    1  33.770         1       0  southeast   1725.55230
# 2   28    1  33.000         3       0  southeast   4449.46200
# 3   33    1  22.705         0       0  northwest  21984.47061
# 4   32    1  28.880         0       0  northwest   3866.85520

# %%
# Check unique values in 'region' column
insurance_df['region'].unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %%
region_dummies = pd.get_dummies(insurance_df['region'], drop_first = True)

# %%
region_dummies
# Out:
#       northwest  southeast  southwest
# 0         False      False       True
# 1         False       True      False
# 2         False       True      False
# 3          True      False      False
# 4          True      False      False
# ...         ...        ...        ...
# 1333       True      False      False
# 1334      False      False      False
# 1335      False       True      False
# 1336      False      False       True
# 1337       True      False      False
#
# [1338 rows x 3 columns]

# %%
insurance_df = pd.concat([insurance_df, region_dummies], axis = 1)

# %%
insurance_df.head()
# Out:
#    age  sex     bmi  children  smoker     region      charges  northwest  \
# 0   19    0  27.900         0       1  southwest  16884.92400      False
# 1   18    1  33.770         1       0  southeast   1725.55230      False
# 2   28    1  33.000         3       0  southeast   4449.46200      False
# 3   33    1  22.705         0       0  northwest  21984.47061       True
# 4   32    1  28.880         0       0  northwest   3866.85520       True
#
#    southeast  southwest
# 0      False       True
# 1       True      False
# 2       True      False
# 3      False      False
# 4      False      False

# %%
# Let's drop the original 'region' column 
insurance_df.drop(['region'], axis = 1, inplace = True)

# %%
insurance_df.head()
# Out:
#    age  sex     bmi  children  smoker      charges  northwest  southeast  \
# 0   19    0  27.900         0       1  16884.92400      False      False
# 1   18    1  33.770         1       0   1725.55230      False       True
# 2   28    1  33.000         3       0   4449.46200      False       True
# 3   33    1  22.705         0       0  21984.47061       True      False
# 4   32    1  28.880         0       0   3866.85520       True      False
#
#    southwest
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False

# %% [markdown]
# # PERFORM DATA VISUALIZATION

# %%
insurance_df[['age', 'sex', 'bmi', 'children', 'smoker', 'charges']].hist(color = 'r', bins = 30, figsize = (12,12))
# Out:
# array([[<Axes: title={'center': 'age'}>, <Axes: title={'center': 'sex'}>],
#        [<Axes: title={'center': 'bmi'}>,
#         <Axes: title={'center': 'children'}>],
#        [<Axes: title={'center': 'smoker'}>,
#         <Axes: title={'center': 'charges'}>]], dtype=object)

# %%
# plot pairplot
sns.pairplot(insurance_df)
# Out:
# <__array_function__ internals>:200: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:200: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:200: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# C:\Users\Tech\anaconda3\envs\MachineLearning\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
plt.figure(figsize = (15, 6))
sns.regplot(x = 'age', y = 'charges', data = insurance_df)
plt.show()

# %%
plt.figure(figsize = (15, 6))
sns.regplot(x = 'bmi', y = 'charges', data = insurance_df)
plt.show()

# %%
insurance_df.corr()
# Out:
#                 age       sex       bmi  children    smoker   charges  \
# age        1.000000 -0.020856  0.109272  0.042469 -0.025019  0.299008
# sex       -0.020856  1.000000  0.046371  0.017163  0.076185  0.057292
# bmi        0.109272  0.046371  1.000000  0.012759  0.003750  0.198341
# children   0.042469  0.017163  0.012759  1.000000  0.007673  0.067998
# smoker    -0.025019  0.076185  0.003750  0.007673  1.000000  0.787251
# charges    0.299008  0.057292  0.198341  0.067998  0.787251  1.000000
# northwest -0.000407 -0.011156 -0.135996  0.024806 -0.036945 -0.039905
# southeast -0.011642  0.017117  0.270025 -0.023066  0.068498  0.073982
# southwest  0.010016 -0.004184 -0.006205  0.021914 -0.036945 -0.043210
#
#            northwest  southeast  southwest
# age        -0.000407  -0.011642   0.010016
# sex        -0.011156   0.017117  -0.004184
# bmi        -0.135996   0.270025  -0.006205
# children    0.024806  -0.023066   0.021914
# smoker     -0.036945   0.068498  -0.036945
# charges    -0.039905   0.073982  -0.043210
# northwest   1.000000  -0.346265  -0.320829
# southeast  -0.346265   1.000000  -0.346265
# southwest  -0.320829  -0.346265   1.000000

# %%
plt.figure(figsize= (10,10))
sns.heatmap(insurance_df.corr(), annot = True)
# Out:
# <Axes: >

# %% [markdown]
# # CREATE TRAINING AND TESTING DATASET

# %%
insurance_df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'charges', 'northwest',
#        'southeast', 'southwest'],
#       dtype='object')

# %%
X = insurance_df.drop(columns = ['charges'])
y = insurance_df['charges']

# %%
X
# Out:
#       age  sex     bmi  children  smoker  northwest  southeast  southwest
# 0      19    0  27.900         0       1      False      False       True
# 1      18    1  33.770         1       0      False       True      False
# 2      28    1  33.000         3       0      False       True      False
# 3      33    1  22.705         0       0       True      False      False
# 4      32    1  28.880         0       0       True      False      False
# ...   ...  ...     ...       ...     ...        ...        ...        ...
# 1333   50    1  30.970         3       0       True      False      False
# 1334   18    0  31.920         0       0      False      False      False
# 1335   18    0  36.850         0       0      False       True      False
# 1336   21    0  25.800         0       0      False      False       True
# 1337   61    0  29.070         0       1       True      False      False
#
# [1338 rows x 8 columns]

# %%
y
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1338, dtype: float64

# %%
X.shape
# Out:
# (1338, 8)

# %%
y.shape
# Out:
# (1338,)

# %%
X = np.array(X).astype('float32')
y = np.array(y).astype('float32')

# %%
y = y.reshape(-1,1)

# %%
# Only take the numerical variables and scale them
X
# Out:
# array([[19.  ,  0.  , 27.9 , ...,  0.  ,  0.  ,  1.  ],
#        [18.  ,  1.  , 33.77, ...,  0.  ,  1.  ,  0.  ],
#        [28.  ,  1.  , 33.  , ...,  0.  ,  1.  ,  0.  ],
#        ...,
#        [18.  ,  0.  , 36.85, ...,  0.  ,  1.  ,  0.  ],
#        [21.  ,  0.  , 25.8 , ...,  0.  ,  0.  ,  1.  ],
#        [61.  ,  0.  , 29.07, ...,  1.  ,  0.  ,  0.  ]], dtype=float32)

# %%
y.shape
# Out:
# (1338, 1)

# %%
#scaling the data before feeding the model
from sklearn.preprocessing import StandardScaler, MinMaxScaler

scaler_x = StandardScaler()
X = scaler_x.fit_transform(X)

scaler_y = StandardScaler()
y = scaler_y.fit_transform(y)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.2, random_state= 10)
print(X_train.shape)
print(X_test.shape)
# Out:
# (1070, 8)
# (268, 8)

# %% [markdown]
# #  TRAIN AND EVALUATE A LINEAR REGRESSION MODEL IN SCIKIT-LEARN

# %%
# using linear regression model
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, accuracy_score

regression_model_sklearn = LinearRegression()
regression_model_sklearn.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
regression_model_sklearn_accuracy = regression_model_sklearn.score(X_test, y_test)
regression_model_sklearn_accuracy
# Out:
# 0.6953286617446484

# %%
y_predict = regression_model_sklearn.predict(X_test)

# %%
y_predict_orig = scaler_y.inverse_transform(y_predict)
y_test_orig = scaler_y.inverse_transform(y_test)

# %%
k = X_test.shape[1]
n = len(X_test)
n
# Out:
# 268

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from math import sqrt


RMSE = float(format(np.sqrt(mean_squared_error(y_test_orig, y_predict_orig)),'.3f'))
MSE = mean_squared_error(y_test_orig, y_predict_orig)
MAE = mean_absolute_error(y_test_orig, y_predict_orig)
r2 = r2_score(y_test_orig, y_predict_orig)
adj_r2 = 1-(1-r2)*(n-1)/(n-k-1)

print('RMSE =',RMSE, '\nMSE =',MSE, '\nMAE =',MAE, '\nR2 =', r2, '\nAdjusted R2 =', adj_r2)
# Out:
# RMSE = 6536.847
# MSE = 42730370.0
# MAE = 4555.099
# R2 = 0.6953286762768424
# Adjusted R2 = 0.6859179790189842

# %% [markdown]
# # TRAIN AND EVALUATE AN ARTIFICIAL NEURAL NETWORK-BASED REGRESSION MODEL

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam

# %%
ANN_model = keras.Sequential()
ANN_model.add(Dense(50, input_dim = 8))
ANN_model.add(Activation('relu'))
ANN_model.add(Dense(150))
ANN_model.add(Activation('relu'))
ANN_model.add(Dense(150))
ANN_model.add(Activation('relu'))
ANN_model.add(Dense(50))
ANN_model.add(Activation('linear'))
ANN_model.add(Dense(1))
ANN_model.compile(loss = 'mse', optimizer = 'adam')
ANN_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 50)                450
#
#  activation (Activation)     (None, 50)                0
#
#  dense_1 (Dense)             (None, 150)               7650
#
#  activation_1 (Activation)   (None, 150)               0
#
#  dense_2 (Dense)             (None, 150)               22650
#
#  activation_2 (Activation)   (None, 150)               0
#
#  dense_3 (Dense)             (None, 50)                7550
#
#  activation_3 (Activation)   (None, 50)                0
#
#  dense_4 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 38351 (149.81 KB)
# Trainable params: 38351 (149.81 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
ANN_model.compile(optimizer='Adam', loss='mean_squared_error')
epochs_hist = ANN_model.fit(X_train, y_train, epochs=100, batch_size = 20, validation_split= 0.2)
# Out:
# Epoch 1/100
# 43/43 [==============================] - 1s 6ms/step - loss: 0.2847 - val_loss: 0.1831
# Epoch 2/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1579 - val_loss: 0.1636
# Epoch 3/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1470 - val_loss: 0.1638
# Epoch 4/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1438 - val_loss: 0.1766
# Epoch 5/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1424 - val_loss: 0.1685
# Epoch 6/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1266 - val_loss: 0.1640
# Epoch 7/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1196 - val_loss: 0.1724
# Epoch 8/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1274 - val_loss: 0.1744
# Epoch 9/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1145 - val_loss: 0.1830
# Epoch 10/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1142 - val_loss: 0.1813
# Epoch 11/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1143 - val_loss: 0.1752
# Epoch 12/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1041 - val_loss: 0.1742
# Epoch 13/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1074 - val_loss: 0.1845
# Epoch 14/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1039 - val_loss: 0.1887
# Epoch 15/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1038 - val_loss: 0.1922
# Epoch 16/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1021 - val_loss: 0.1883
# Epoch 17/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0968 - val_loss: 0.1838
# Epoch 18/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0950 - val_loss: 0.2029
# Epoch 19/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0961 - val_loss: 0.1995
# Epoch 20/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0904 - val_loss: 0.2038
# Epoch 21/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0949 - val_loss: 0.2014
# Epoch 22/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0945 - val_loss: 0.1972
# Epoch 23/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0939 - val_loss: 0.1935
# Epoch 24/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0904 - val_loss: 0.2085
# Epoch 25/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0899 - val_loss: 0.2181
# Epoch 26/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0846 - val_loss: 0.2303
# Epoch 27/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0909 - val_loss: 0.1999
# Epoch 28/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0819 - val_loss: 0.2131
# Epoch 29/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0780 - val_loss: 0.2098
# Epoch 30/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0828 - val_loss: 0.2067
# Epoch 31/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0778 - val_loss: 0.2142
# Epoch 32/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0719 - val_loss: 0.2126
# Epoch 33/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0793 - val_loss: 0.2128
# Epoch 34/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0747 - val_loss: 0.2164
# Epoch 35/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0709 - val_loss: 0.2141
# Epoch 36/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0698 - val_loss: 0.2259
# Epoch 37/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0670 - val_loss: 0.2247
# Epoch 38/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0650 - val_loss: 0.2195
# Epoch 39/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0656 - val_loss: 0.2199
# Epoch 40/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0681 - val_loss: 0.2182
# Epoch 41/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0611 - val_loss: 0.2178
# Epoch 42/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0601 - val_loss: 0.2387
# Epoch 43/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0550 - val_loss: 0.2246
# Epoch 44/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0563 - val_loss: 0.2262
# Epoch 45/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0638 - val_loss: 0.2322
# Epoch 46/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0581 - val_loss: 0.2302
# Epoch 47/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0573 - val_loss: 0.2157
# Epoch 48/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0544 - val_loss: 0.2376
# Epoch 49/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0545 - val_loss: 0.2376
# Epoch 50/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0532 - val_loss: 0.2384
# Epoch 51/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0520 - val_loss: 0.2678
# Epoch 52/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0571 - val_loss: 0.2354
# Epoch 53/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0524 - val_loss: 0.2288
# Epoch 54/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0511 - val_loss: 0.2296
# Epoch 55/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0530 - val_loss: 0.2182
# Epoch 56/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0481 - val_loss: 0.2456
# Epoch 57/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0459 - val_loss: 0.2431
# Epoch 58/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0448 - val_loss: 0.2354
# Epoch 59/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0473 - val_loss: 0.2305
# Epoch 60/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0423 - val_loss: 0.2343
# Epoch 61/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0462 - val_loss: 0.2268
# Epoch 62/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0414 - val_loss: 0.2414
# Epoch 63/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0467 - val_loss: 0.2461
# Epoch 64/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0473 - val_loss: 0.2518
# Epoch 65/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0435 - val_loss: 0.2455
# Epoch 66/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0392 - val_loss: 0.2320
# Epoch 67/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0418 - val_loss: 0.2475
# Epoch 68/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0404 - val_loss: 0.2544
# Epoch 69/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0414 - val_loss: 0.2387
# Epoch 70/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0384 - val_loss: 0.2393
# Epoch 71/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0376 - val_loss: 0.2337
# Epoch 72/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0370 - val_loss: 0.2460
# Epoch 73/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0359 - val_loss: 0.2365
# Epoch 74/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0395 - val_loss: 0.2420
# Epoch 75/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0370 - val_loss: 0.2642
# Epoch 76/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0389 - val_loss: 0.2346
# Epoch 77/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0357 - val_loss: 0.2365
# Epoch 78/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0350 - val_loss: 0.2474
# Epoch 79/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0341 - val_loss: 0.2362
# Epoch 80/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0337 - val_loss: 0.2588
# Epoch 81/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0408 - val_loss: 0.2508
# Epoch 82/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0364 - val_loss: 0.2420
# Epoch 83/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0342 - val_loss: 0.2516
# Epoch 84/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0355 - val_loss: 0.2288
# Epoch 85/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0303 - val_loss: 0.2459
# Epoch 86/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0399 - val_loss: 0.2587
# Epoch 87/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0388 - val_loss: 0.2389
# Epoch 88/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0377 - val_loss: 0.2283
# Epoch 89/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0364 - val_loss: 0.2371
# Epoch 90/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0358 - val_loss: 0.2341
# Epoch 91/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0333 - val_loss: 0.2355
# Epoch 92/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0305 - val_loss: 0.2440
# Epoch 93/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0296 - val_loss: 0.2413
# Epoch 94/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0284 - val_loss: 0.2456
# Epoch 95/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0289 - val_loss: 0.2596
# Epoch 96/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0323 - val_loss: 0.2528
# Epoch 97/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0299 - val_loss: 0.2697
# Epoch 98/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0267 - val_loss: 0.2445
# Epoch 99/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0272 - val_loss: 0.2394
# Epoch 100/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0309 - val_loss: 0.2403

# %%
result = ANN_model.evaluate(X_test, y_test)
accuracy_ANN = 1 - result
print("Accuracy : {}".format(accuracy_ANN))
# Out:
# 9/9 [==============================] - 0s 1ms/step - loss: 0.2972
# Accuracy : 0.7028318643569946

# %%
epochs_hist.history.keys()
# Out:
# dict_keys(['loss', 'val_loss'])

# %%
plt.plot(epochs_hist.history['loss'])
plt.plot(epochs_hist.history['val_loss'])
plt.title('Model Loss Progress During Training')
plt.xlabel('Epoch')
plt.ylabel('Training and Validation Loss')
plt.legend(['Training Loss', 'Validation Loss'])

# %%
y_predict = ANN_model.predict(X_test)
plt.plot(y_test, y_predict, "^", color = 'r')
plt.xlabel('Model Predictions')
plt.ylabel('True Values')
# Out:
# 9/9 [==============================] - 0s 1ms/step
# Text(0, 0.5, 'True Values')

# %%
y_predict_orig = scaler_y.inverse_transform(y_predict)
y_test_orig = scaler_y.inverse_transform(y_test)

# %%
plt.plot(y_test_orig, y_predict_orig, "^", color = 'r')
plt.xlabel('Model Predictions')
plt.ylabel('True Values')
# Out:
# Text(0, 0.5, 'True Values')

# %%
k = X_test.shape[1]
n = len(X_test)
n

from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from math import sqrt

RMSE = float(format(np.sqrt(mean_squared_error(y_test_orig, y_predict_orig)),'.3f'))
MSE = mean_squared_error(y_test_orig, y_predict_orig)
MAE = mean_absolute_error(y_test_orig, y_predict_orig)
r2 = r2_score(y_test_orig, y_predict_orig)
adj_r2 = 1-(1-r2)*(n-1)/(n-k-1)

print('RMSE =',RMSE, '\nMSE =',MSE, '\nMAE =',MAE, '\nR2 =', r2, '\nAdjusted R2 =', adj_r2)
# Out:
# RMSE = 6599.079
# MSE = 43547840.0
# MAE = 3855.8816
# R2 = 0.6895000378412318
# Adjusted R2 = 0.6799093054193394
